# %%
from __future__ import print_function
from astropy.io import fits
from astropy.nddata import Cutout2D
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import os

# %%
path = '/Users/quinncasey/Desktop/research/eboss/0.1-bin/0.1-spec-files-less'

# %%
for root, directories, files in os.walk(path, topdown=False):
    for name in files:
        print(os.path.join(root, name))
# Out:
# /Users/quinncasey/Desktop/research/eboss/0.1-bin/0.1-spec-files-less/5298/spec-5298-55979-0880.fits
# /Users/quinncasey/Desktop/research/eboss/0.1-bin/0.1-spec-files-less/6986/spec-6986-56717-0276.fits
# /Users/quinncasey/Desktop/research/eboss/0.1-bin/0.1-spec-files-less/7032/spec-7032-56471-0053.fits
# /Users/quinncasey/Desktop/research/eboss/0.1-bin/0.1-spec-files-less/7310/spec-7310-56693-0844.fits
# /Users/quinncasey/Desktop/research/eboss/0.1-bin/0.1-spec-files-less/8197/spec-8197-57064-0290.fits

# %%
hdu = fits.open('/Users/quinncasey/Desktop/research/eboss/0.1-bin/0.1-spec-files-less/5298/spec-5298-55979-0880.fits')
hdu1 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.1-bin/0.1-spec-files-less/6986/spec-6986-56717-0276.fits')
hdu2 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.1-bin/0.1-spec-files-less/7032/spec-7032-56471-0053.fits')
hdu3 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.1-bin/0.1-spec-files-less/7310/spec-7310-56693-0844.fits')
hdu4 = fits.open('/Users/quinncasey/Desktop/research/eboss/0.1-bin/0.1-spec-files-less/8197/spec-8197-57064-0290.fits')

# %%
loglam = 10**(hdu[1].data['LOGLAM'])
flux = hdu[1].data['FLUX']
z = hdu[2].data['Z']

wavelength = (loglam)/(1+z)

plt.style.use('grayscale')
plt.xlabel('R-Frame Wavelength ($\AA$)')
plt.title('5298-55979-0880')
plt.plot(wavelength, flux, alpha=0.5)

# %%
loglam1 = 10**(hdu1[1].data['LOGLAM'])
flux1 = hdu1[1].data['FLUX']
z1 = hdu1[2].data['Z']

wavelength1 = (loglam1)/(1+z1)

plt.style.use('grayscale')
plt.xlabel('R-Frame Wavelength ($\AA$)')
plt.title('6986-56717-0276')
plt.plot(wavelength1, flux1, alpha=0.5)

# %%
loglam2 = 10**(hdu2[1].data['LOGLAM'])
flux2 = hdu2[1].data['FLUX']
z2 = hdu2[2].data['Z']

wavelength2 = (loglam2)/(1+z)

plt.style.use('grayscale')
plt.xlabel('R-Frame Wavelength ($\AA$)')
plt.title('7032-56471-0053')
plt.plot(wavelength2, flux2, alpha=0.5)

# %%
loglam3 = 10**(hdu3[1].data['LOGLAM'])
flux3 = hdu3[1].data['FLUX']
z3 = hdu3[2].data['Z']

wavelength3 = (loglam3)/(1+z3)

plt.style.use('grayscale')
plt.xlabel('R-Frame Wavelength ($\AA$)')
plt.title('7310-56693-0844')
plt.plot(wavelength3, flux3, alpha=0.5)

# %%
loglam4 = 10**(hdu4[1].data['LOGLAM'])
flux4 = hdu4[1].data['FLUX']
z4 = hdu4[2].data['Z']

wavelength4 = (loglam4)/(1+z4)

plt.style.use('grayscale')
plt.xlabel('R-Frame Wavelength ($\AA$)')
plt.title('8197-57064-0290')
plt.plot(wavelength4, flux4, alpha=0.5)
